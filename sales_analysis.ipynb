# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('sales_data.csv')
print(df.head())

sales_by_product = df.groupby('product')['sales'].sum()
print(sales_by_product)

sales_by_product.plot(kind="bar", title="Sales by Product")
plt.ylabel("Sales amount")
plt.show()

sales_by_category = df.groupby('category')['sales'].sum()
sales_by_category.plot(kind="pie", title="Sales by Category", autopct='%1.1f%%')
plt.show()
# Out:
#          date     product       category  sales
# 0  2025-01-01   Chocolate           Food    378
# 1  2025-01-01       Chips           Food    157
# 2  2025-01-01       Juice      Beverages    238
# 3  2025-01-01   Chocolate           Food     90
# 4  2025-01-01  Toothpaste  Personal Care     65
# product
# Biscuits       752
# Chips          385
# Chocolate     1284
# Juice          702
# Shampoo       1549
# Soap           141
# Tea           1037
# Toothpaste      65
# Name: sales, dtype: int64
